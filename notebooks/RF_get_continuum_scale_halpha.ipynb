# %% [markdown]
# # Continuum subtractions
#
# * Working with Gautam to get the continuum scale factor for each galaxy in the halpha sample.
#
# * we are reporting the scale factor in the halpha-galaxies-including-duplicates
#
#
# ## Workflow
#
# * need to rsync directory from draco
# * then run subtract_continuum.py

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
homedir = os.getenv("HOME")
# %matplotlib inline

# %%
dirname = 'VFID0377-IC1210-BOK-20210414-VFID0422'


os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# add scale factor for continuue after the directory name
scalefactor = .96

# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
# %run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  0.96
#
# VFID0377: halpha filter correction = 1.004
#
# halpha extinction correction =  1.0276948968772757
# Subtracting 1.62e-04 from r-band image
# Subtracting 1.03e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID0377-legacy-226-gr-ha-smooth.fits
# telescope =  BOK VFID0377-IC1210-BOK-20210414-VFID0422
#
# Generate NET image
#
# Computing median values for r and halpha images
# currently, I am not subtracting these, so check values...
# Subtracting -1.30e-02 from r-band image
# Subtracting -6.95e-03 from halpha image
# Unbinned SB limit 1sigma 2.39e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 2.57e-03 e-18
# scale factors for sfr image: a=2.25e-70, b=5.51e+12, c=2.09e+53, product=2.59e-04
# STD cut in SF image = 6.297e-06

# %%
2949.03/3
# Out:
# 983.0100000000001
