# %% [markdown]
# # Continuum subtractions
#
# * Working with Gautam to get the continuum scale factor for each galaxy in the halpha sample.
#
# * we are reporting the scale factor in the halpha-galaxies-including-duplicates
#
#
# ## Workflow
#
# * need to rsync directory from draco
# * then run subtract_continuum.py

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
homedir = os.getenv("VFID0538-NGC3835-BOK-20210417-VFID0520HOME")
# %matplotlib inline

# %%
# %matplotlib inline
plt.figure()
x = np.arange(10)
plt.plot(x,x)

# %%
dirname = 'VFID0377-IC1210-BOK-20210414-VFID0422'
scalefactor = 1.02

dirname = 'VFID0385-MCG+10-23-067-BOK-20210414-VFID0422'
scalefactor = 1.

dirname = 'VFID0422-ARK499-BOK-20210414-VFID0422'
scalefactor = 1.0

dirname = 'VFID0448-UGC10745-BOK-20220424-VFID0483'
scalefactor = 1.0

dirname = 'VFID0469-SDSSJ114145.90+605931.9-BOK-20210417-VFID0520'
scalefactor = 1.0 # 1.03 from auto, ok

dirname = 'VFID0473-WISEAJ170712.75+605514.5-BOK-20220424-VFID0483'
scalefactor = 1.05

dirname = 'VFID0473-WISEAJ170712.75+605514.5-INT-20190603-p010'
scalefactor = 1.0

# dirname = 'VFID0474-WISEAJ114424.53+605302.6-BOK-20210417-VFID0520'
# scalefactor = 1.0

# dirname = 'VFID0481-NGC6307-BOK-20220424-VFID0483'
# scalefactor = 1.0

#dirname = 'VFID0481-NGC6307-INT-20190603-p010'
#scalefactor = .96

dirname = 'VFID0496-WISEAJ114601.22+603006.0-BOK-20210417-VFID0520'
# auto is giving 1.09, which looks like oversubtraction
scalefactor = 1.0

# cleaning up directory after reaching VFID05XX


# dirname = 'VFID1167-MESSIER109-INT-20220501-VFID1168'
# scalefactor = .95

dirname = 'VFID0501-UGC09556-BOK-20210315-VFID0501'
scalefactor = 1.12


dirname = 'VFID0520-NGC3796-BOK-20210417-VFID0520'
scalefactor = 1.14


dirname = 'VFID0569-NGC5989-INT-20190530-p002'
scalefactor = 1.0

dirname = 'VFID0601-NGC5976-BOK-20220424-VFID0607'
scalefactor = 1.0

dirname = 'VFID0602-NGC5981-BOK-20220424-VFID0607'
scalefactor = 1.0

dirname = 'VFID0610-NGC5985-BOK-20220424-VFID0607'
scalefactor = 1.0

# add scale factor for continuue after the directory name

dirname = 'VFID0625-GALEX2680919432329433855-BOK-20220424-VFID0607'
scalefactor = 1.05

dirname = 'VFID0637-WISEAJ150535.77+590537.2-BOK-20210414-VFID0638'
scalefactor = 1.02

dirname = 'VFID0650-NGC5777-BOK-20220423-VFID0651'
scalefactor = 1.05

dirname  = 'VFID0680-WISEAJ114552.80+584811.0-BOK-20210418-VFID0788'
scalefactor = 1.15

dirname = 'VFID0691-SBS1144+590-BOK-20210418-VFID0788'
scalefactor = 1.09

os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.09
#
# VFID0691: halpha filter correction = 1.012
#
# halpha extinction correction =  1.0272851259153346
# Subtracting 4.60e-04 from r-band image
# Subtracting 2.48e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID0691-legacy-60-gr-ha-smooth.fits
# telescope =  BOK VFID0691-SBS1144+590-BOK-20210418-VFID0788
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting -3.61e-02 from r-band image
# Subtracting -4.77e-03 from halpha image
# Unbinned SB limit 1sigma 2.46e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 2.05e-03 e-18

# %%
# starting at 0700's

dirname = 'VFID0703-WISEAJ114603.32+583621.6-BOK-20210418-VFID0788'
scalefactor = 1.09



os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.09
#
# VFID0703: halpha filter correction = 1.069
#
# halpha extinction correction =  1.0270803017086547
# Subtracting 2.87e-04 from r-band image
# Subtracting 1.35e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID0703-legacy-59-gr-ha-smooth.fits
# telescope =  BOK VFID0703-WISEAJ114603.32+583621.6-BOK-20210418-VFID0788
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting -1.23e-02 from r-band image
# Subtracting 2.24e-03 from halpha image
# Unbinned SB limit 1sigma 2.78e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 2.95e-03 e-18

# %%
# without boxcar smoothing of R-band data
## looks better

dirname = 'VFID1167-MESSIER109-INT-20220501-VFID1168'
scalefactor = .94

dirname = 'VFID0715-SBS1143+588-BOK-20210418-VFID0788'
scalefactor = 1.09


dirname = 'VFID0719-MRK0847-BOK-20220423-VFID0720'
scalefactor = 1.04

dirname = 'VFID0731-SDSSJ151827.05+582658.5-BOK-20220423-VFID0720'
scalefactor = 1.07

dirname = 'VFID0775-UGC09837-BOK-20220425-VFID0776'
scalefactor = 1.06

dirname = 'VFID0782-UGC10968-BOK-20220423-VFID0783'
scalefactor = 1.04

dirname = 'VFID0782-UGC10968-INT-20190531-p012'
scalefactor = 1.05

dirname = 'VFID0787-NGC3838-BOK-20210418-VFID0788'
scalefactor = 1.07

dirname = 'VFID0796-CGCG292-024-BOK-20210418-VFID0788'
scalefactor = 1.01

#######################################################
## SUBTRACT CONTINUUM
#######################################################

os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.01
#
# VFID0796: halpha filter correction = 1.098
#
# halpha extinction correction =  1.017702403058096
# Subtracting 6.23e-04 from r-band image
# Subtracting 4.77e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID0796-legacy-102-gr-ha-smooth.fits
# telescope =  BOK VFID0796-CGCG292-024-BOK-20210418-VFID0788
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting -3.80e-02 from r-band image
# Subtracting 1.40e-03 from halpha image
# Unbinned SB limit 1sigma 2.21e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 1.99e-03 e-18

# %%
# 900's !!!
dirname = 'VFID0935-WISEAJ114820.15+562045.4-INT-20220502-VFID0957'
scalefactor = 1.0

dirname = 'VFID0956-NGC3898-INT-20220502-VFID0957'
scalefactor = 1.05

dirname = 'VFID0958-SDSSJ114929.60+560154.1-INT-20220502-VFID0957'
scalefactor = 1.04

dirname = 'VFID0959-NGC3888-INT-20220502-VFID0957'
scalefactor = 1.15 # can't get a good continuum subtraction, probably b/c filter correction is > 2
# remove from sample 

dirname = 'VFID0970-WISEAJ114634.08+554917.4-INT-20220502-VFID0957'
scalefactor = 1.05

dirname = 'VFID0990-UGC06919-INT-20220502-VFID1010'
scalefactor = 1.04

dirname = 'VFID1008-NGC3990-INT-20220502-VFID1010'
scalefactor = .96

dirname = 'VFID1014-WISEAJ115701.80+552510.7-INT-20220502-VFID1010'
scalefactor = 1.0

dirname = 'VFID1018-NGC3972-INT-20220502-VFID1010'
scalefactor = 1.03 # no idea why this cutout is so big!

dirname = 'VFID1035-NGC3982-INT-20220502-VFID1010'
scalefactor = 1.05

dirname = 'VFID1163-UGC06969-INT-20220501-VFID1168'
scalefactor = 1.05

dirname = 'VFID1167-MESSIER109-INT-20220501-VFID1168'
scalefactor = .95

dirname = 'VFID1168-WISEAJ115834.38+532043.3-INT-20220501-VFID1168'
scalefactor = .95 # using the same value as above b/c can't tell from image

dirname = 'VFID1170-UGC06940-INT-20220501-VFID1168'
scalefactor = 1.03

dirname = 'VFID1174-UGC06923-INT-20220501-VFID1168'
scalefactor = 1.

dirname = 'VFID1212-NGC3953-INT-20220503-VFID1213'
scalefactor = 1.01

dirname = 'VFID1221-UGC06840-INT-20220503-VFID1213' # cutout is missing
scalefactor = 1.1

dirname = 'VFID1275-NGC4026-INT-20220503-VFID1277'
scalefactor = .98

dirname = 'VFID1277-UGC06956-INT-20220503-VFID1277'
scalefactor = 1.0

dirname = 'VFID1287-SDSSJ120549.54+504729.0-INT-20220501-VFID1304'
scalefactor = .96

dirname = 'VFID1297-UGC06992-INT-20220503-VFID1277'
scalefactor = 1.08

dirname = 'VFID1302-NGC4088-INT-20220501-VFID1304'
scalefactor = .99


dirname = 'VFID1316-NGC4085-INT-20220501-VFID1304'
scalefactor = 1.0

dirname = 'VFID1363-UGC04551-INT-20190206-p013'
scalefactor = 1.0

dirname = 'VFID1374-NGC4100-INT-20220503-VFID1376'
scalefactor = 1.02

dirname = 'VFID1461-WISEAJ111345.42+482405.5-BOK-20210315-VFID1538'
scalefactor = 1.0

dirname = 'VFID1473-NGC3583-BOK-20210315-VFID1538'
scalefactor = 1.0

dirname = 'VFID1532-NGC4096-INT-20220502-VFID1534'
scalefactor = 1.03


dirname = 'VFID1536-NGC3595-BOK-20210315-VFID1538'
scalefactor = 1.03

dirname = 'VFID1552-UGC04659-INT-20190206-p017'
scalefactor = 1.03

dirname = 'VFID1559-WISEAJ133318.59+470228.0-BOK-20210315-VFID1573'
scalefactor = 1.0

dirname = 'VFID1571-IC4263-BOK-20210315-VFID1573'
scalefactor = 1.0

dirname = 'VFID1588-NGC5169-HDI-20170523-p023'
scalefactor = 1.0

dirname = 'VFID1588-NGC5169-BOK-20210315-VFID1573'
scalefactor = 1.02
#######################################################
## SUBTRACT CONTINUUM
#######################################################

os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.02
#
# VFID1588: halpha filter correction = 1.019
#
# halpha extinction correction =  1.0639778821768
# Subtracting 1.17e-04 from r-band image
# Subtracting 6.68e-05 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID1588-legacy-436-gr-ha-smooth.fits
# telescope =  BOK VFID1588-NGC5169-BOK-20210315-VFID1573
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting -2.87e-03 from r-band image
# Subtracting -2.44e-03 from halpha image
# Unbinned SB limit 1sigma 2.07e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 1.92e-03 e-18

# %% [markdown]
# # New approach using NoMachine
#
# * logging in directly to draco
#
# ```
# cd /data-pool/Halpha/halphagui-output-20240522/cutouts
# ipython --pylab
#
# ```
#
#
# ### Sticking with laptop...
# ```
# cd /media/rfinn/hdata2/halphagui-output-20240522/cutouts
# rsync -avz --exclude="mastDownloads" draco:/data-pool/Halpha/halphagui-output-20240522/cutouts/VF*BOK* .
# ```

# %%
dirname = 'VFID1589-NGC5198-BOK-20210315-VFID1573'
scalefactor = .97

dirname = 'VFID1589-NGC5198-HDI-20170523-p023'
scalefactor = 1.0


dirname = 'VFID1593-NGC5173-HDI-20170523-p023'
scalefactor = 1.01

dirname = 'VFID1593-NGC5173-BOK-20210315-VFID1573'
scalefactor = .97


dirname = 'VFID1594-WISEAJ133245.70+463506.7-BOK-20210315-VFID1573'
scalefactor = 1.0

dirname = 'VFID1595-WISEAJ132951.25+463456.9-BOK-20210315-VFID1573'
scalefactor = .97 # based on other images. would have picked 0.98 otherwise

dirname = 'VFID1595-WISEAJ132951.25+463456.9-BOK-20210315-VFID1573'
scalefactor = 1.0


dirname = 'VFID1604-CGCG246-006-BOK-20210315-VFID1573'
scalefactor = 1.0 # based on other images

dirname = 'VFID1604-CGCG246-006-HDI-20170523-p023'
scalefactor = 1.03 

dirname = 'VFID1605-MCG+08-25-006-BOK-20210315-VFID1573'
scalefactor = 1.0 # based on other images

dirname = 'VFID1605-MCG+08-25-006-HDI-20170523-p023'
scalefactor = 1.0 # based on other images

dirname = 'VFID1628-CGCG246-005-HDI-20170523-p023'
scalefactor = 1.03 # based on other images

dirname = 'VFID1648-MCG+08-16-005-HDI-20200224-p002'
scalefactor = 1. 

dirname = 'VFID1654-UGC04393-HDI-20200224-p002'
scalefactor = 1. 

dirname = 'VFID1681-SDSSJ090003.58+453425.7-BOK-20210315-VFID1728'
scalefactor = 1.0 # based on other images

dirname = 'VFID1726-NGC2712-BOK-20210315-VFID1728'
scalefactor = 1.01

dirname = 'VFID1726-NGC2712-INT-20190205-p019'
scalefactor = .97


dirname = 'VFID1754-NGC4051-INT-20220504-VFID1756'
scalefactor = .97


dirname = 'VFID1789-NGC5297-BOK-20220425-VFID1791'
scalefactor = 1.02


dirname = 'VFID1792-NGC5296-BOK-20220425-VFID1791'
scalefactor = 1.02 # based on previous image

dirname = 'VFID1793-UGC08798-BOK-20210418-VFID1821'
scalefactor = 1.0

dirname = 'VFID1802-CGCG218-049-BOK-20210418-VFID1821'
scalefactor = 1.0 # based on prior galaxy

dirname = 'VFID1802-CGCG218-049-BOK-20220425-VFID1791'
scalefactor = 1.03

dirname = 'VFID1804-NGC4138-INT-20220502-VFID1806'
scalefactor = .97

dirname = 'VFID1807-WISEAJ134857.31+433600.0-BOK-20210418-VFID1821'
scalefactor = 1.03 # hard to tell b/c very little continuum

dirname = 'VFID1807-WISEAJ134857.31+433600.0-BOK-20220425-VFID1791'
scalefactor = 1.1 # hard to tell b/c very little continuum

dirname = 'VFID1811-UGC08767-BOK-20210418-VFID1821'
scalefactor = 1.0

dirname = 'VFID1817-UGC07271-INT-20220503-VFID1819'
scalefactor = 1.0

dirname = 'VFID1819-UGC08733-BOK-20210418-VFID1821'
scalefactor = 1.0

dirname = 'VFID1819-UGC08733-BOK-20220425-VFID1791'
scalefactor = 1.01

dirname = 'VFID1820-KUG1008+436-BOK-20210416-VFID1844'
scalefactor = 1.

dirname = 'VFID1830-NGC5336-BOK-20210418-VFID1821'
scalefactor = 1.03

dirname = 'VFID1832-UGC07146-BOK-20210414-VFID1901'
scalefactor = 1.03

dirname = 'VFID1842-IC0598-BOK-20210416-VFID1844'
scalefactor = 1.0

dirname = 'VFID1844-UGC07089-INT-20220504-VFID1855'
scalefactor = .96

dirname = 'VFID1847-SDSSJ135202.34+430741.7-BOK-20210418-VFID1821'
scalefactor = 1.0

dirname = 'VFID1848-NGC4117-INT-20220504-VFID1855'
scalefactor = 1.01

dirname = 'VFID1850-NGC4118-INT-20220504-VFID1855'
scalefactor = 1.01 # this is in the cutout above

dirname = 'VFID1853-NGC4111-INT-20220504-VFID1855'
scalefactor = .97 

dirname = 'VFID1865-UGC07094-INT-20220504-VFID1855'
scalefactor = .97 

dirname = 'VFID1870-SDSSJ120559.53+425409.5-INT-20220504-VFID1855'
scalefactor = 1.0

dirname = 'VFID1899-NGC4143-BOK-20210414-VFID1901'
scalefactor = 1.01

dirname = 'VFID1912-SDSSJ135749.50+421329.5-BOK-20220424-VFID1944'
scalefactor = 1.03

dirname = 'VFID1921-WISEAJ134434.71+421009.9-BOK-20220425-VFID1979'
scalefactor = 1.01

dirname = 'VFID1923-WISEAJ091743.52+420804.6-INT-20190205-p026'
scalefactor = 1.00

# dirname = 'VFID1933-NGC2798-INT-20190205-p026'
# scalefactor = 1.03

# dirname = 'VFID1934-NGC2799-INT-20190205-p026'
# scalefactor = 1.03 # in image with above

dirname = 'VFID1939-UGC04904-INT-20190205-p026'
scalefactor = 1.05

dirname = 'VFID1942-NGC5383-BOK-20220424-VFID1944'
scalefactor = 1.03

dirname = 'VFID1944-UGC08877-BOK-20220424-VFID1944'
scalefactor = 1.03

dirname = 'VFID1949-WISEAJ134548.60+414443.7-BOK-20220425-VFID1979'
scalefactor = .97 # based on image below

dirname = 'VFID1953-NGC5290-BOK-20220425-VFID1979'
scalefactor = .97

dirname = 'VFID1954-MRK1484-BOK-20220425-VFID1979'
scalefactor = .98

dirname = 'VFID1954-MRK1484-HDI-20170523-p019'
scalefactor = 1.05

dirname = 'VFID1957-WISEAJ134414.89+414037.6-BOK-20220425-VFID1979'
scalefactor = 1 # can't tell, something weird here in terms of what I'm seeing here vs what is on webpage

dirname = 'VFID1962-SDSSJ134529.67+413831.0-BOK-20220425-VFID1979'
scalefactor = .99
 
dirname = 'VFID1964-WISEAJ134900.04+413758.6-BOK-20220425-VFID1979'
scalefactor = 1.0

dirname = 'VFID1964-WISEAJ134900.04+413758.6-HDI-20170523-p019'
scalefactor = 1. # almost pure continuum - hard to tell

dirname = 'VFID1974-WISEAJ134445.84+413323.8-BOK-20220425-VFID1979'
scalefactor = .99

dirname = 'VFID1977-NGC5289-BOK-20220425-VFID1979'
scalefactor = 1.0

dirname = 'VFID1977-NGC5289-BOK-20220425-VFID1979'
scalefactor = 1.0

dirname = 'VFID1988-NGC5320-HDI-20170523-p019'
scalefactor = 1.01

dirname = 'VFID1993-NGC5362-INT-20190211-p121'
scalefactor = 1.03

dirname = 'VFID1994-UGCA373-BOK-20220425-VFID1979'
scalefactor = 1.01


#######################################################
## SUBTRACT CONTINUUM
#######################################################

os.chdir('/media/rfinn/hdata2/halphagui-output-20240522/cutouts/')
# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.01
#
# VFID1994: halpha filter correction = 1.010
#
# halpha extinction correction =  1.0118343060637238
# Subtracting 1.82e-04 from r-band image
# Subtracting 1.55e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID1994-legacy-112-gr-ha-smooth.fits
# telescope =  BOK VFID1994-UGCA373-BOK-20220425-VFID1979
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting 4.64e-04 from r-band image
# Subtracting -2.26e-03 from halpha image
# Unbinned SB limit 1sigma 2.34e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 2.70e-03 e-18

# %% [markdown]
# # VFID2000s

# %%
dirname = 'VFID2011-WISEAJ135527.51+410819.9-BOK-20210417-VFID2068'
scalefactor = 1.0

dirname = 'VFID2011-WISEAJ135527.51+410819.9-BOK-20220425-VFID2078'
scalefactor = 1.0

dirname = 'VFID2011-WISEAJ135527.51+410819.9-INT-20190211-p121'
scalefactor = 1 # fairly high filter corr - getting both absorption and emission

dirname = 'VFID2039-WISEAJ135407.50+404901.3-BOK-20210417-VFID2068'
scalefactor = .96

dirname = 'VFID2039-WISEAJ135407.50+404901.3-BOK-20220425-VFID2078'
scalefactor = .97

dirname = 'VFID2040-UGC08807-BOK-20210417-VFID2068'
scalefactor = 1.03

dirname = 'VFID2040-UGC08807-BOK-20220425-VFID2078'
scalefactor = 1.02

dirname = 'VFID2049-SDSSJ135504.83+403417.5-BOK-20210417-VFID2068'
scalefactor = .9 # absorption

dirname = 'VFID2049-SDSSJ135504.83+403417.5-BOK-20220425-VFID2078'
scalefactor = .93

dirname = 'VFID2049-SDSSJ135504.83+403417.5-HDI-20170522-p016'
scalefactor = 1.

dirname = 'VFID2055-SDSSJ135414.16+402838.5-BOK-20210417-VFID2068'
scalefactor = 1.0

dirname = 'VFID2055-SDSSJ135414.16+402838.5-BOK-20220425-VFID2078'
scalefactor = 1.0

dirname = 'VFID2055-SDSSJ135414.16+402838.5-HDI-20170522-p016'
scalefactor = 1.0

dirname = 'VFID2056-WISEAJ092313.64+402755.9-INT-20190206-p028'
scalefactor = 1.03

dirname = 'VFID2057-NGC5371-BOK-20210417-VFID2068'
scalefactor = 1.0

dirname = 'VFID2057-NGC5371-BOK-20220425-VFID2078'
scalefactor = 1.0

dirname = 'VFID2057-NGC5371-HDI-20170522-p016'
scalefactor = 1.0

dirname = 'VFID2060-WISEAJ135103.75+402550.8-HDI-20180316-p054'
scalefactor = 1.0

dirname = 'VFID2066-NGC5350-BOK-20210417-VFID2068'
scalefactor = 1. # swamped by bright star


dirname = 'VFID2070-WISEAJ135318.84+401900.5-BOK-20210417-VFID2068'
scalefactor = 1. # swamped by bright star


dirname = 'VFID2066-NGC5350-HDI-20170522-p016'
scalefactor = 1. # swamped by bright star

#dirname = 'VFID2072-PGC10049356NED036-BOK-20210417-VFID2068'
#scalefactor = 1. # swamped by bright star

#######################################################
## SUBTRACT CONTINUUM
#######################################################

os.chdir('/media/rfinn/hdata2/halphagui-output-20240522/cutouts/')
# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.0
#
# VFID2066: halpha filter correction = 1.023
#
# halpha extinction correction =  1.0191239315082525
# Subtracting 1.40e-03 from r-band image
# Subtracting 8.66e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID2066-legacy-431-gr-ha-smooth.fits
# telescope =  HDI VFID2066-NGC5350-HDI-20170522-p016
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting -4.62e-02 from r-band image
# Subtracting -5.07e-03 from halpha image
# Unbinned SB limit 1sigma 8.94e-03 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 1.33e-03 e-18

# %%
5/.43
# Out:
# 11.627906976744185

# %%
# without boxcar smoothing of R-band data
# and without g-r smoothing


dirname = 'VFID1167-MESSIER109-INT-20220501-VFID1168'
scalefactor = .95




os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# add scale factor for continuue after the directory name
# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.07
#
# VFID0731: halpha filter correction = 1.006
#
# halpha extinction correction =  1.017702403058096
# Subtracting 2.56e-04 from r-band image
# Subtracting 2.30e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID0731-legacy-83-gr-ha-smooth.fits
# telescope =  BOK VFID0731-SDSSJ151827.05+582658.5-BOK-20220423-VFID0720
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting -5.52e-03 from r-band image
# Subtracting -3.09e-03 from halpha image
# Unbinned SB limit 1sigma 2.74e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 3.38e-03 e-18

# %%
# %run ~/github/Virgo/programs/readtablesv2.py

# %%
# plot halpha FWHM vs R

x = v.halpha['R_FWHM']
y = v.halpha['H_FWHM']

flag = v.main['HAflag']

#plt.scatter(x[flag],y[flag],c=v.halpha['TEL'][flag])

tels = set(v.halpha['TEL'][flag])
for t in tels:
    flag1 = v.halpha['TEL'] == t
    plt.scatter(x[flag&flag1],y[flag&flag1],s=50,label=t,alpha=.5)
    diff = (x[flag&flag1] - y[flag&flag1])/([x[flag&flag1]])
    print(f"{t} rms = {np.std(diff):.2f}")


xline = np.linspace(1,3,100)
plt.plot(xline,1.1*xline,'k--',label='+/-10%')
plt.plot(xline,0.9*xline,'k--')
plt.plot(xline,1.2*xline,'k:',label='+/-20%')
plt.plot(xline,0.8*xline,'k:')
plt.xlabel("R-band FWHM",fontsize=16)
plt.ylabel("H-alpha FWHM",fontsize=16)
    
plt.legend()
# Out:
# HDI rms = 0.15
# INT rms = 0.10
# BOK rms = 0.10
# MOS rms = 0.04

# %%
v.main
# Out:
# <Table length=6780>
#   VFID           RA         ... unwiseflag               prefix
#                             ...
#  bytes8       float64       ...    bool                 bytes36
# -------- ------------------ ... ---------- ---------------------------------
# VFID0000 185.86877249999998 ...      False                  VFID0000-NGC4363
# VFID0001            182.208 ...      False                  VFID0001-NGC4133
# VFID0002         145.944663 ...      False                  VFID0002-NGC2977
# VFID0003        185.5730835 ...      False              VFID0003-CGCG352-030
# VFID0004 182.82775049999998 ...      False                 VFID0004-UGC07189
# VFID0005        173.1341835 ...       True                  VFID0005-NGC3752
# VFID0006         121.912404 ...      False                 VFID0006-UGC04202
# VFID0007           118.2363 ...      False              VFID0007-KUG0746+747
# VFID0008         274.943166 ...      False                  VFID0008-NGC6643
# ...
