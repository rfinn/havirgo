# %% [markdown]
# # Example Procedure for Subtracting Continuum

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
homedir = os.getenv("HOME")

# %% [markdown]
# # Example 1
#
#
# VFID6486-NGC5831-BOK-20220428-VFID6503

# %%
os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')

# %%
# !rsync --exclude "mastDownload" -avz draco:/data-pool/Halpha/halphagui-output-20240104/cutouts/VFID6486-NGC5831-BOK* .
# Out:
# rfinn@199.223.244.32's password:
# rsync error: received SIGINT, SIGTERM, or SIGHUP (code 20) at rsync.c(644) [Receiver=3.1.2]

# %%
# image is oversubtracted, so I am adjusted the continuum

os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# add scale factor for continuue after the directory name
dirname = 'VFID6486-NGC5831-BOK-20220428-VFID6503'
scalefactor = .95

# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
# %run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  0.95
#
# VFID6486: halpha filter correction = 1.024
#
# halpha extinction correction =  1.104621266154606
# Subtracting -8.17e-05 from r-band image
# Subtracting -9.34e-05 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID6486-legacy-425-gr-ha-smooth.fits
# telescope =  BOK VFID6486-NGC5831-BOK-20220428-VFID6503
#
# Generate NET image
#
# Computing median values for r and halpha images
# currently, I am not subtracting these, so check values...
# Subtracting -3.35e-02 from r-band image
# Subtracting -3.58e-03 from halpha image
# Unbinned SB limit 1sigma 2.31e-02 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 3.14e-03 e-18
# scale factors for sfr image: a=2.37e-70, b=5.51e+12, c=6.67e+52, product=8.72e-05
# STD cut in SF image = 2.061e-06

# %% [markdown]
# # Example 2
#
# VFID6473-WISEAJ150606.72+011920.9-MOS-20110404-NGC5846_01

# %%
dirname = 'VFID6473-WISEAJ150606.72+011920.9-MOS-20110404-NGC5846_01'


os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# add scale factor for continuue after the directory name
scalefactor = 1

# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
# %run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.0
#
# VFID6473: halpha filter correction = 1.024
#
# halpha extinction correction =  1.1108059567260404
# Subtracting 3.08e-04 from r-band image
# Subtracting 1.63e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID6473-legacy-59-gr-ha-smooth.fits
# telescope =  MOS VFID6473-WISEAJ150606.72+011920.9-MOS-20110404-NGC5846_01
#
# Generate NET image
#
# Computing median values for r and halpha images
# currently, I am not subtracting these, so check values...
# Subtracting -7.92e-03 from r-band image
# Subtracting 4.48e-03 from halpha image
# Unbinned SB limit 1sigma 2.67e-03 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 5.24e-04 e-18
# scale factors for sfr image: a=1.17e-69, b=5.51e+12, c=1.33e+53, product=8.56e-04
# STD cut in SF image = 2.067e-06
