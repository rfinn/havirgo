# %% [markdown]
# # Following on from duplicates
#
# * will use duplicates and cross-match to vf tables
#
#
# ### Plots to make
# * SFR - Mstar

# %%
from astropy.io import fits
from matplotlib import pyplot as plt
from astropy.table import Table
import os
import numpy as np
from scipy.stats import median_abs_deviation as MAD
# %matplotlib inline

# %%
# %run ~/github/havirgo/python/hanalysis.py
d.compare_ratios(hsmorphmaxflag=3,rsmorphmaxflag=2)
# Out:
# WARNING: UnitsWarning: ''dex'' did not parse as fits unit: At col 0, Unit ''dex'' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'log(solMass)' did not parse as fits unit: 'log' is not a recognized function If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# ...

# %%
# %run ~/github/havirgo/python/hanalysis.py
d.plot_sfr_mstar(hsmorphmaxflag=3,rsmorphmaxflag=2)
# Out:
# number of galaxies observed in halpha =  868
# number after removing bad flag =  774
# number of duplicate observations = 153
# /Users/rfinn/github/havirgo/python/hanalysis.py:64: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bv" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x[self.htab['VFINDEX'][flag2]],y[self.htab['VFINDEX'][flag2]],'bv',c=mycolors[3],mec='k',alpha=.7,label=f'Halpha ~STAMORPH ({np.sum(flag2)})',markersize=9)
# /Users/rfinn/github/havirgo/python/hanalysis.py:65: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bs" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x[self.htab['VFINDEX'][flag4]],y[self.htab['VFINDEX'][flag4]],'bs',c=mycolors[0],mec='k',alpha=.8,label=f'Halpha STATMORPH ({np.sum(flag4)})',markersize=9)

# %%
# %run ~/github/havirgo/python/hanalysis.py
d.plot_mstar_hist(hsmorphmaxflag=3,rsmorphmaxflag=2)
# Out:
# number of galaxies observed in halpha =  868
# number after removing bad flag =  774
# number of duplicate observations = 153
# [47. 48. 32. 37.  2.]
# [ 9.000019   9.3999768  9.7999346 10.1998924 10.5998502 10.999808 ]
# 166.0

# %%
12000/300
# Out:
# 40.0

# %% [markdown]
# # Compare Size vs Environment

# %%
# %run ~/github/havirgo/python/hanalysis.py
d.plot_sizeratio_environment()
# Out:
# number of galaxies observed in halpha =  868
# number after removing bad flag =  774
# number of duplicate observations = 153
# /Users/rfinn/github/havirgo/python/hanalysis.py:87: RuntimeWarning: invalid value encountered in true_divide
#   sizeratio = self.htab['SMORPH_HR80']/self.htab['SMORPH_R80']
# pure_field 44
# poor_group_memb 98
# filament_member 255
# rich_group_memb 197
# KstestResult(statistic=0.22033898305084745, pvalue=0.045812913534934)

# %%
# %run ~/github/havirgo/python/hanalysis.py
d.plot_giniratio_environment()
# Out:
# number of galaxies observed in halpha =  868
# number after removing bad flag =  774
# number of duplicate observations = 153
# pure_field 44
# poor_group_memb 98
# filament_member 255
# rich_group_memb 197
# KstestResult(statistic=0.1590909090909091, pvalue=0.2720912867410442)

# %%
d.smorphflag[(d.htab['VFID'] == 'VFID5855')]
# Out:
# masked_array(data=[ True],
#              mask=False,
#        fill_value=True)

# %%
d.smorphflag[(d.htab['VFID'] == 'VFID5842')]
# Out:
# masked_array(data=[ True, False],
#              mask=False,
#        fill_value=True)

# %%
d.smorphflagh[(d.htab['VFID'] == 'VFID5842')]
# Out:
# masked_array(data=[ True, False],
#              mask=False,
#        fill_value=True)

# %%
d.smorphflagr[(d.htab['VFID'] == 'VFID5842')]
# Out:
# masked_array(data=[ True,  True],
#              mask=False,
#        fill_value=True)

# %%
d.sizeratio[(d.htab['VFID'] == 'VFID5842')]
# Out:
# <Column name='SMORPH_HR80' dtype='float32' length=2>
#  0.5452593
# 0.64793766

# %%
# %run ~/github/havirgo/python/hanalysis.py
d.plot_sizeratio_conc_environment()
# Out:
# number of galaxies observed in halpha =  868
# number after removing bad flag =  774
# number of duplicate observations = 153
# /Users/rfinn/github/havirgo/python/hanalysis.py:111: RuntimeWarning: invalid value encountered in true_divide
#   sizeratio = self.htab['SMORPH_HR80']/self.htab['SMORPH_R80']
# /Users/rfinn/github/havirgo/python/hanalysis.py:112: RuntimeWarning: invalid value encountered in true_divide
#   xvariable = self.htab['SMORPH_R20']/self.htab['SMORPH_R80']
# pure_field 44
# SpearmanrResult(correlation=0.22460269931841145, pvalue=0.14271453517088353)
# poor_group_memb 98
# SpearmanrResult(correlation=-0.3570113612455291, pvalue=0.0003311531157322561)
# filament_member 255
# SpearmanrResult(correlation=-0.17152766714431683, pvalue=0.008274310374850203)
# rich_group_memb 197
# SpearmanrResult(correlation=-0.06899580726879138, pvalue=0.36705970791479936)
# all environments:  SpearmanrResult(correlation=-0.12473625098111304, pvalue=0.015105854491826477)

# %%
2011.3-1995.5
# Out:
# 15.799999999999955
