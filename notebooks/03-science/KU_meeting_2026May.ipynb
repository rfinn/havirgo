# %%
import os
import sys
import numpy as np
from matplotlib import pyplot as plt
from astropy.io import fits
from astropy.table import Table
homedir = os.getenv("HOME")
sys.path.append(os.path.join(homedir,'github/hapy/scripts/'))

# %%
# %run ~/github/Virgo/programs/readtablesv2.py
merged = '/Users/rfinn/research/Virgo/hatools_test/hapy-output-20260330/merged_results.fits'
hapy = Table.read(merged)
vfindex = np.zeros(len(hapy))

for i in range(len(hapy)):
    vfindex[i] = int(hapy['VFID'][i].replace('VFID',''))
vfindex = np.array(vfindex,'i')
# Out:
# table directory =  /Users/rfinn/research/Virgo/tables-north/v2/
# WARNING: UnitsWarning: ''dex'' did not parse as fits unit: At col 0, Unit ''dex'' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'log(solMass)' did not parse as fits unit: 'log' is not a recognized function If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# ...

# %%
from qc_helpers import

# %% [markdown]
# # Delta Gini, Delta M20, colored by filling factor

# %%
# %run ~/github/hapy/scripts/science_morphology.py $merged --scheme virgo
# Out:
# Read 823 rows from /Users/rfinn/research/Virgo/hatools_test/hapy-output-20260330/merged_results.fits
# REVIEW_PRIORITY SUMMARY
# {'high': 90, 'low': 319, 'medium': 414}
# ELL_MISMATCH 267
# FILTER_WARNING 79
# WARN_MASK 10
# BRIGHT_STAR_FLAG 0
# WARN_WEAK_HA 260

# %%
tab.colnames
# Out:
# ['VFID',
#  'GALNAME',
#  'OBJID',
#  'RA',
#  'DEC',
#  'REDSHIFT',
#  'VR',
#  'HAPY_VERSION',
#  'RUN_DATE',
#  'TELESCOPE',
#  'DATEOBS',
#  'POINTING',
#  'SCHEME',
#  'PARENT_RIMAGE',
#  'PARENT_HIMAGE',
#  'HFILTER',
#  'PIXSCALE',
#  'TAG',
#  'CUTDIR',
#  'MASK_FITS',
#  'PSF_FITS',
#  'R_FITS',
#  'CS_FITS',
#  'RFILTER_FILENAME',
#  'RFILTER_CENTER',
#  'RFILTER_WIDTH',
#  'HFILTER_FILENAME',
#  'HFILTER_CENTER',
#  'HFILTER_WIDTH',
#  'PSF_SOURCE',
#  'STAGE',
#  'STATUS',
#  'MASK_SEC',
#  'PHOT_SEC',
#  'SM_SEC',
#  'GAL_NC_SEC',
#  'GAL_CV_SEC',
#  'TOTAL_SEC',
#  'PSF_OK',
#  'MASK_OK',
#  'PHOT_OK',
#  'HAPY_MORPH_OK',
#  'R_PROFILE_OK',
#  'H_PROFILE_OK',
#  'R_SM_OK',
#  'H_SM_OK',
#  'GAL_NC_OK',
#  'GAL_CV_OK',
#  'GAL_CV_INIT_FROM_NC',
#  'GAL_NC_RERUN_FIXEDN',
#  'GAL_CV_RERUN_FIXEDN',
#  'ELL_MISMATCH',
#  'R_PETRO_OK',
#  'R_EXPFIT_OK',
#  'R_LOGFIT_OK',
#  'H_PETRO_OK',
#  'H_EXPFIT_OK',
#  'H_LOGFIT_OK',
#  'BRIGHT_STAR_FLAG',
#  'BRIGHT_STAR_DIST_ARCSEC',
# ...

# %%
x = tab['DELTA_M20']
y = tab['DELTA_GINI']
c = tab['H_HAPY_FILLFRAC']
c = tab['QC_TIER']
clabel = 'Halpha Filling Fraction'
plt.figure()
sc = plt.scatter(x,y,c=c,alpha=.6)
cb = plt.colorbar(label=clabel)

plt.xlabel(r"$\rm \Delta M_{20}$",fontsize=16)


plt.ylabel(r"$\rm \Delta Gini$",fontsize=16)
plt.axhline(ls='--',color='0.5')
plt.axvline(ls='--',color='0.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/virgo/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4618, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4617 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4618     colors = mcolors.to_rgba_array(c)
#    4619 except (TypeError, ValueError) as err:
#
# File ~/anaconda3/envs/virgo/lib/python3.11/site-packages/matplotlib/colors.py:512, in to_rgba_array(c, alpha)
#     511 else:
# --> 512     rgba = np.array([to_rgba(cc) for cc in c])
#     514 if alpha is not None:
#
# File ~/anaconda3/envs/virgo/lib/python3.11/site-packages/matplotlib/colors.py:512, in <listcomp>(.0)
#     511 else:
# --> 512     rgba = np.array([to_rgba(cc) for cc in c])
#     514 if alpha is not None:
#
# ...
