# %% [markdown]
# # ALMA galaxies
#
# * need to get continuum-subtracted Halpha galaxies
# * overplot ALMA contours
# * overplot MeerKAT HI contours
#
#
# ### Galaxies
#
# VFID5855-NGC5348
# VFID5842-NGC5356
# VFID6018-NGC5560
# VFID6033-NGC5566
# VFID6091-NGC5577
# VFID6362-UGC09661

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
homedir = os.getenv("HOME")

# %%
alldirs = ['VFID5855-NGC5348-INT-20190206-p120',\
          'VFID5842-NGC5356-INT-20190206-p120',\
          'VFID6018-NGC5560-INT-20190208-p131',\
          'VFID6033-NGC5566-INT-20190208-p131',\
          'VFID6091-NGC5577-INT-20190207-p134',\
          'VFID6362-UGC09661-BOK-20210418-VFID6406',\
          'VFID6362-UGC09661-MOS-20110404-NGC5846_02']

scalefactors = np.ones(len(alldirs))

# %%
# image is oversubtracted, so I am adjusted the continuum

os.chdir(homedir+'/research/Virgo-dev/cont-sub-gr')
# add scale factor for continuue after the directory name
dirname = alldirs[2]
scalefactor = 1

# %run ~/github/havirgo/python/subtract_continuum.py $dirname $scalefactor
#%run ~/github/havirgo/python/subtract_continuum_auto.py $dirname 
# %run ~/github/havirgo/python/make_mstar_image.py $dirname 0
#%run ~/github/havirgo/python/get_gr_cont_phot.py $dirname
#%run ~/github/havirgo/python/get_mstar_sfr_phot.py $dirname
# Out:
# In subtract continuum, continuum scale factor =  1.0
#
# VFID6018: halpha filter correction = 1.060
#
# halpha extinction correction =  1.0534225237823107
# Subtracting 3.47e-04 from r-band image
# Subtracting 1.82e-04 from g-band image
# Smoothing images for color calculation
# writing g-r color image to legacy/VFID6018-legacy-582-gr-ha-smooth.fits
# telescope =  INT VFID6018-NGC5560-INT-20190208-p131
#
# Generate NET image
#
# Computing median values for r and halpha images
# subtracting these values from the image...
# Subtracting -3.24e-02 from r-band image
# Subtracting 1.33e-04 from halpha image
# Unbinned SB limit 1sigma 8.77e-03 e-18
# Smoothing net image
# Smoothed 15x15 SB limit 1sigma 1.17e-03 e-18
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/github/havirgo/python/make_mstar_image.py in <module>
#     400     g.construct_filenames()
#     401     g.get_mstar_image()
# --> 402     g.get_sfr_image()
#     403     g.get_ssfr_image()
#     404     g.save_figure(zoom=zoomflag,zoomfactor=2.)
#
# ~/github/havirgo/python/make_mstar_image.py in get_sfr_image(self, makeplots, verbose)
#     173
#     174         # read in continuum-subtracted image
# --> 175         hahdu = fits.open(self.ha)
#     176         self.haheader = hahdu[0].header
#     177         hZP = hahdu[0].header['PHOTZP']
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#     212         raise ValueError(f"Empty filename: {name!r}")
#     213
# --> 214     return HDUList.fromfile(
#     215         name,
#     216         mode,
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     480         """
#     481
# --> 482         return cls._readfrom(
#     483             fileobj=fileobj,
#     484             mode=mode,
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#    1168             if not isinstance(fileobj, _File):
#    1169                 # instantiate a FITS file object (ffo)
# -> 1170                 fileobj = _File(
#    1171                     fileobj,
#    1172                     mode=mode,
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs)
#     216             self._open_fileobj(fileobj, mode, overwrite)
#     217         elif isinstance(fileobj, (str, bytes)):
# --> 218             self._open_filename(fileobj, mode, overwrite)
#     219         else:
#     220             self._open_filelike(fileobj, mode, overwrite)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     634
#     635         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 636             self._file = open(self.name, IO_FITS_MODES[mode])
#     637             self.close_on_error = True
#     638
#
# FileNotFoundError: [Errno 2] No such file or directory: 'VFID6018-NGC5560-INT-20190208-p131-CS-gr-auto.fits'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ImportError: dlopen(/Users/rfinn/anaconda3/lib/python3.8/site-packages/cv2/cv2.abi3.so, 0x0002): Library not loaded: /opt/local/lib/libx265.179.dylib
#   Referenced from: <A19395ED-6B75-3FD1-BF71-071890DB1721> /opt/local/lib/libavcodec.58.91.100.dylib
#   Reason: tried: '/opt/local/lib/libx265.179.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/local/lib/libx265.179.dylib' (no such file), '/opt/local/lib/libx265.179.dylib' (no such file), '/usr/local/lib/libx265.179.dylib' (no such file), '/usr/lib/libx265.179.dylib' (no such file, not in dyld cache)Library not loaded: /opt/local/lib/libx265.179.dylib
#   Referenced from: <18134C13-D7CA-3D31-85F7-9EA644E1A016> /opt/local/lib/libavformat.58.45.100.dylib
#   Reason: tried: '/opt/local/lib/libx265.179.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/local/lib/libx265.179.dylib' (no such file), '/opt/local/lib/libx265.179.dylib' (no such file), '/usr/local/lib/libx265.179.dylib' (no such file), '/usr/lib/libx265.179.dylib' (no such file, not in dyld cache)
